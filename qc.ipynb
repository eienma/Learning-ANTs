# %%
from nilearn import plotting
import nibabel as nib
from matplotlib import pyplot as plt

# %%
reg_type = 's_s'

# %%
plotting.plot_img("I:\\ants\\anat\\sub-08_T1w_brain.nii.gz")
plotting.plot_img("I:\\ants\\func\\example_func.nii.gz")
plotting.plot_img("I:\\ants\\"+reg_type+"\\reg_a2t_Warped.nii.gz")
plotting.plot_img("I:\\ants\\"+reg_type+"\\reg_f2a_Warped.nii.gz")
plotting.plot_img("I:\\ants\\"+reg_type+"\\example_fun2standard.nii.gz")
image = nib.load("I:\\ants\\"+reg_type+"\\example_fun2standard.nii.gz")
image_data = image.get_fdata()
print(image_data.shape)
# Out:
# (91, 109, 91)

# %%
image = nib.load('I:\\ants\\example_fun2standard.nii.gz')
image_data = image.get_fdata()
print(image_data.shape)
plotting.plot_img("I:\\ants\\example_fun2standard.nii.gz")
# Out:
# (91, 109, 91)
